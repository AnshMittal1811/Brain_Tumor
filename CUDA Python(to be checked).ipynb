# %%
#%%writefile filename.py
import numpy as np
from timeit import default_timer as timer
from matplotlib import pyplot
import math
import os 
os.environ['NUMBAPRO_CUDALIB']='Anaconda3/envs/cudaenv/Library/bin'
from numba import vectorize, cuda
from pyculib import rand as curand
import cProfile as profile

#@vectorize(["float64(float64, float64, float64, float64, float64)"], target = "cuda")
@cuda.jit('void(double[:], double[:], double, double, double, double[:])')
def step(nextPrices, lastPrices, dt, c0, c1, noise):
    i = cuda.blockIdx.x * cuda.blockDim.x + cuda.threadIdx.x
    i = cuda.grid(1)
    if (i >= nextPrices.shape[0]):
        return
    nextPrices[i] = lastPrices[i] * math.exp(c0 * dt + c1 * noise[i])




def montecarlo(paths, dt, interest, volatility):
    c0 = interest - 0.5 * volatility **2
    c1 = volatility * np.sqrt(dt)
    
    prng = curand.PRNG(rndtype = curand.PRNG.XORWOW)
    d_noises = cuda.device_array(paths.shape[0])
    
    d_current = cuda.to_device(paths[:,0])
    d_next = cuda.device_array(paths.shape[0])
    
    threadsPerBlock = 256
    
    numBlocks =(paths.shape[0] + threadsPerBlock-1)/threadsPerBlock 
    
    for j in range(1, paths.shape[1]):      #for each time step
        #prices = paths[:, j - 1]            #last prices # Now no slicing needed
        #gaussian noise for simulation
        #noises = np.random.normal(0., 1., prices.size)
        prng.normal(d_noises, 0., 1.)
        #simulate
        #d_next = step(d_current, dt, c0, c1, d_noises)
        step[numBlocks, threadsPerBlock](d_next, d_current, dt, c0, c1, d_noises)
        
        d_next.copy_to_host(paths[:,j])
            
        d_next, d_current = d_current, d_next
        
        
#Stock Information Parameters
StockPrice = 20.83
StrikePrice = 21.50
Volatility = 0.021
InterestRate = 0.20
Maturity = 5. / 12.


#monte carlo simulation parameters
NumPath = 3000000
NumStep = 100


#plotting 
MAX_PATH_IN_PLOT = 50


def driver(pricer, do_plot=False):
    paths = np. zeros((NumPath, NumStep + 1), order ='F')
    paths[:, 0] = StockPrice
    DT = Maturity / NumStep
    
    ts = timer()
    pricer(paths, DT, InterestRate, Volatility)
    te = timer()
    elapsed = te - ts
    
    ST = paths[:, -1]
    PaidOff = np. maximum(paths[:, -1] - StrikePrice, 0)
    print('Result')
    fmt = '%20s: %s'
    print(fmt % ('stock price', np.mean(ST)))
    print(fmt % ('standard error', np.std(ST) / np.sqrt(NumPath)))
    print(fmt % ('paid off', np.mean(PaidOff)))
    optionprice = np.mean(PaidOff) * np.exp(-InterestRate * Maturity)
    print(fmt % ('option price', optionprice))
    
    print('Performance')
    NumCompute = NumPath * NumStep
    print(fmt % ('Mstep/second', '%.2f' % (NumCompute / elapsed / 1e6)))
    print(fmt % ('time elapsed', '%.3fs' % (te - ts)))
    
    if do_plot:
        pathct = min(NumPath, MAX_PATH_IN_PLOT)
        for i in range(pathct):
            pyplot.plot(paths[i])
        print('Plotting %d/%d paths' % (pathct, NumPath))
        pyplot.show()

        
#driver(montecarlo, do_plot = False)
driver(montecarlo, do_plot = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5cc6b8a7df3c> in <module>()
#     101
#     102 #driver(montecarlo, do_plot = False)
# --> 103 driver(montecarlo, do_plot = False)
#
# <ipython-input-9-5cc6b8a7df3c> in driver(pricer, do_plot)
#      73
#      74     ts = timer()
# ---> 75     pricer(paths, DT, InterestRate, Volatility)
#      76     te = timer()
#      77     elapsed = te - ts
#
# <ipython-input-9-5cc6b8a7df3c> in montecarlo(paths, dt, interest, volatility)
#      43         #simulate
#      44         #d_next = step(d_current, dt, c0, c1, d_noises)
# ---> 45         step[numBlocks, threadsPerBlock](d_next, d_current, dt, c0, c1, d_noises)
#      46
#      47         d_next.copy_to_host(paths[:,j])
#
# ~\Anaconda3\envs\cudaenv\lib\site-packages\numba\cuda\compiler.py in __getitem__(self, args)
#     303         if len(args) not in [2, 3, 4]:
#     304             raise ValueError('must specify at least the griddim and blockdim')
# --> 305         return self.configure(*args)
#     306
#     307     def forall(self, ntasks, tpb=0, stream=0, sharedmem=0):
#
# ~\Anaconda3\envs\cudaenv\lib\site-packages\numba\cuda\compiler.py in configure(self, griddim, blockdim, stream, sharedmem)
#     291
#     292     def configure(self, griddim, blockdim, stream=0, sharedmem=0):
# --> 293         griddim, blockdim = normalize_kernel_dimensions(griddim, blockdim)
#     294
#     295         clone = self.copy()
#
# ~\Anaconda3\envs\cudaenv\lib\site-packages\numba\cuda\errors.py in normalize_kernel_dimensions(griddim, blockdim)
#      36         return dim
#      37
# ---> 38     griddim = check_dim(griddim, 'griddim')
#      39     blockdim = check_dim(blockdim, 'blockdim')
#      40
#
# ~\Anaconda3\envs\cudaenv\lib\site-packages\numba\cuda\errors.py in check_dim(dim, name)
#      31             if not isinstance(v, numbers.Integral):
#      32                 raise TypeError('%s must be a sequence of integers, got %r'
# ---> 33                                 % (name, dim))
#      34         while len(dim) < 3:
#      35             dim.append(1)
#
# TypeError: griddim must be a sequence of integers, got [11719.74609375]
